# %% [markdown]
# <a href="https://colab.research.google.com/github/watcharakiete/TOC-Assignment/blob/master/Color_distinguish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://4.bp.blogspot.com/-ukjUU_JJ6y0/WxVha1617oI/AAAAAAAAXr8/xrXPfl2DWyE-WdxvBct-HCLYt_cwbO5owCLcBGAs/s400/yourname-02m22s.png
# Out:
# --2020-10-21 13:30:05--  https://4.bp.blogspot.com/-ukjUU_JJ6y0/WxVha1617oI/AAAAAAAAXr8/xrXPfl2DWyE-WdxvBct-HCLYt_cwbO5owCLcBGAs/s400/yourname-02m22s.png
# Resolving 4.bp.blogspot.com (4.bp.blogspot.com)... 108.177.125.132, 2404:6800:4008:c01::84
# Connecting to 4.bp.blogspot.com (4.bp.blogspot.com)|108.177.125.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 161458 (158K) [image/png]
# Saving to: ‘yourname-02m22s.png’
#
# yourname-02m22s.png 100%[===================>] 157.67K  --.-KB/s    in 0.002s
#
# 2020-10-21 13:30:06 (84.6 MB/s) - ‘yourname-02m22s.png’ saved [161458/161458]

# %%
import matplotlib.pyplot as plt
import cv2

originalImage = cv2.imread('/content/yourname-02m22s.png')
plt.imshow(cv2.cvtColor(originalImage, cv2.COLOR_BGR2RGB))
plt.ylabel('original')
plt.show()

# %%
print(originalImage.shape)
x,y,dim = originalImage.shape
#get what x,y,color?
print(originalImage[0][0][2])
# Out:
# (225, 400, 3)
# 113

# %%
 import colorsys
 print(colorsys.rgb_to_hls(191, 191, 191)[2])
# Out:
# 0.0

# %%
for i in range(x):
  for j in range(y):
    r = originalImage[i][j][0]
    g = originalImage[i][j][1]
    b = originalImage[i][j][2]
